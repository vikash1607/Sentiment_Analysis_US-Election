# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import wordcloud

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from textblob import TextBlob
from tensorflow.keras.preprocessing.text import Tokenizer
from nltk.sentiment.util import *

# %%
biden=pd.read_csv("/content/drive/MyDrive/sentimentdata/hashtag_joebiden.csv",lineterminator='\n')

# %%
biden.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:18  1.316529e+18
# 2  2020-10-15 00:00:20  1.316529e+18
# 3  2020-10-15 00:00:21  1.316529e+18
# 4  2020-10-15 00:00:22  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  #HunterBiden #HunterBidenEmails #JoeBiden #Joe...    0.0            0.0
# 2  @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...    0.0            0.0
# 3  @chrislongview Watching and setting dvr. Let’s...    0.0            0.0
# 4  #censorship #HunterBiden #Biden #BidenEmails #...    1.0            0.0
#
#                source       user_id           user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08  El Sol Latino News  elsollatinonews
# 1    Twitter for iPad  8.099044e+08         Cheri A. 🇺🇸     Biloximeemaw
# 2     Twitter Web App  3.494182e+09          Flag Waver      Flag_Wavers
# 3  Twitter for iPhone  8.242596e+17       Michelle Ferg    MichelleFerg4
# 4     Twitter Web App  1.032807e+18      the Gold State    theegoldstate
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Locked and loaded Meemaw. Love God, my family ...  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4  A Silicon Valley #independent #News #Media #St...  ...
#
#   user_followers_count                 user_location        lat        long  \
# 0               1860.0  Philadelphia, PA / Miami, FL  25.774270  -80.193660
# 1               6628.0                           NaN        NaN         NaN
# 2               1536.0         Golden Valley Arizona  46.304036 -109.171431
# 3                 27.0                           NaN        NaN         NaN
# 4                390.0               California, USA  36.701463 -118.755997
#
#    city                   country      continent       state state_code  \
# 0   NaN  United States of America  North America     Florida         FL
# 1   NaN                       NaN            NaN         NaN        NaN
# 2   NaN  United States of America  North America     Montana         MT
# 3   NaN                       NaN            NaN         NaN        NaN
# 4   NaN  United States of America  North America  California         CA
#
#                     collected_at
# 0            2020-10-21 00:00:00
# 1  2020-10-21 00:00:00.517827283
# 2  2020-10-21 00:00:01.035654566
# 3  2020-10-21 00:00:01.553481849
# 4  2020-10-21 00:00:02.071309132
#
# [5 rows x 21 columns]

# %%
trump=pd.read_csv("/content/drive/MyDrive/sentimentdata/hashtag_donaldtrump.csv",lineterminator='\n')

# %%
trump['candidate']='trump'

# %%
biden['candidate']='biden'

# %%
trump.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:01  1.316529e+18
# 2  2020-10-15 00:00:02  1.316529e+18
# 3  2020-10-15 00:00:02  1.316529e+18
# 4  2020-10-15 00:00:08  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2  #Trump: As a student I used to hear for years,...    2.0            1.0
# 3  2 hours since last tweet from #Trump! Maybe he...    0.0            0.0
# 4  You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
#
#                source       user_id              user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08     El Sol Latino News  elsollatinonews
# 1    Social Mediaset   3.316176e+08                Tgcom24  MediasetTgcom24
# 2     Twitter Web App  8.436472e+06                 snarke           snarke
# 3       Trumpytweeter  8.283556e+17          Trumpytweeter    trumpytweeter
# 4  Twitter for iPhone  4.741380e+07  Rana Abtar - رنا أبتر        Ranaabtar
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Profilo ufficiale di Tgcom24: tutte le notizie...  ...
# 2  Will mock for food! Freelance writer, blogger,...  ...
# 3  If he doesn't tweet for some time, should we b...  ...
# 4  Washington Correspondent, Lebanese-American ,c...  ...
#
#                   user_location        lat        long        city  \
# 0  Philadelphia, PA / Miami, FL  25.774270  -80.193660         NaN
# 1                           NaN        NaN         NaN         NaN
# 2                      Portland  45.520247 -122.674195    Portland
# 3                           NaN        NaN         NaN         NaN
# 4                 Washington DC  38.894992  -77.036558  Washington
#
#                     country      continent                 state state_code  \
# 0  United States of America  North America               Florida         FL
# 1                       NaN            NaN                   NaN        NaN
# 2  United States of America  North America                Oregon         OR
# 3                       NaN            NaN                   NaN        NaN
# 4  United States of America  North America  District of Columbia         DC
#
#                     collected_at candidate
# 0            2020-10-21 00:00:00     trump
# 1  2020-10-21 00:00:00.373216530     trump
# 2  2020-10-21 00:00:00.746433060     trump
# 3  2020-10-21 00:00:01.119649591     trump
# 4  2020-10-21 00:00:01.492866121     trump
#
# [5 rows x 22 columns]

# %%
data_mixed=pd.concat([trump,biden])

# %%
data_mixed
# Out:
#                  created_at      tweet_id  \
# 0       2020-10-15 00:00:01  1.316529e+18
# 1       2020-10-15 00:00:01  1.316529e+18
# 2       2020-10-15 00:00:02  1.316529e+18
# 3       2020-10-15 00:00:02  1.316529e+18
# 4       2020-10-15 00:00:08  1.316529e+18
# ...                     ...           ...
# 776881  2020-11-08 23:59:38  1.325589e+18
# 776882  2020-11-08 23:59:38  1.325589e+18
# 776883  2020-11-08 23:59:41  1.325589e+18
# 776884  2020-11-08 23:59:52  1.325589e+18
# 776885  2020-11-08 23:59:58  1.325589e+18
#
#                                                     tweet  likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0
# 1       Usa 2020, Trump contro Facebook e Twitter: cop...   26.0
# 2       #Trump: As a student I used to hear for years,...    2.0
# 3       2 hours since last tweet from #Trump! Maybe he...    0.0
# 4       You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# ...                                                   ...    ...
# 776881  Stop laying @CNN !\n#Paris and #London dont gi...    0.0
# 776882  Ωχ ελπίζω να μη μας βγει  σαν τους οπαδούς του...    0.0
# 776883  L'OTAN va sortir de sa léthargie et redevenir ...   48.0
# 776884  🌎\n\n“#congiuntifuoriregione”\n\n‘Sono felice ...    1.0
# 776885  Ik moet zeggen dat ik #Biden "the lesser of tw...    0.0
#
#         retweet_count               source       user_id  \
# 0                 0.0            TweetDeck  3.606665e+08
# 1                 9.0     Social Mediaset   3.316176e+08
# 2                 1.0      Twitter Web App  8.436472e+06
# 3                 0.0        Trumpytweeter  8.283556e+17
# 4                 3.0   Twitter for iPhone  4.741380e+07
# ...               ...                  ...           ...
# 776881            0.0   Twitter for iPhone  3.873620e+08
# 776882            0.0  Twitter for Android  4.032819e+08
# 776883           14.0  Twitter for Android  7.819183e+17
# 776884            1.0   Twitter for iPhone  5.293315e+08
# 776885            0.0  Twitter for Android  5.863863e+08
#
#                                          user_name user_screen_name  \
# 0                               El Sol Latino News  elsollatinonews
# 1                                          Tgcom24  MediasetTgcom24
# 2                                           snarke           snarke
# 3                                    Trumpytweeter    trumpytweeter
# 4                            Rana Abtar - رنا أبتر        Ranaabtar
# ...                                            ...              ...
# 776881                                     flaquet         flaquet1
# 776882                     οχι άλλο κάρβουνο 🇬🇷🗣🗣🗣         anapodoi
# 776883  🇫🇷 Alt-Droite (matricule 6921) ✝️ 🇬🇷 🇮🇹 🇦🇲    CtrlAltDroite
# 776884                                 Angelo Tani       AngeloTani
# 776885                                         Job          _JobO__
#
#                                          user_description  ...  \
# 0       🌐 Noticias de interés para latinos de la costa...  ...
# 1       Profilo ufficiale di Tgcom24: tutte le notizie...  ...
# 2       Will mock for food! Freelance writer, blogger,...  ...
# 3       If he doesn't tweet for some time, should we b...  ...
# 4       Washington Correspondent, Lebanese-American ,c...  ...
# ...                                                   ...  ...
# 776881                                                NaN  ...
# 776882       ακραία καιρικά φαινόμενα... ζήσαμε και απόψε  ...
# 776883  Fils de mineur. Libertés - Identité - Solidari...  ...
# 776884                              nato a casa dei nonni  ...
# 776885                -voeg hier uw interessante bio toe-  ...
#
#                        user_location        lat        long        city  \
# 0       Philadelphia, PA / Miami, FL  25.774270  -80.193660         NaN
# 1                                NaN        NaN         NaN         NaN
# 2                           Portland  45.520247 -122.674195    Portland
# 3                                NaN        NaN         NaN         NaN
# 4                      Washington DC  38.894992  -77.036558  Washington
# ...                              ...        ...         ...         ...
# 776881                         PARIS  48.856697    2.351462       Paris
# 776882                           NaN        NaN         NaN         NaN
# 776883                        France  46.603354    1.888334         NaN
# 776884                             🌎        NaN         NaN         NaN
# 776885                           NaN        NaN         NaN         NaN
#
#                          country      continent                 state  \
# 0       United States of America  North America               Florida
# 1                            NaN            NaN                   NaN
# 2       United States of America  North America                Oregon
# 3                            NaN            NaN                   NaN
# 4       United States of America  North America  District of Columbia
# ...                          ...            ...                   ...
# 776881                    France         Europe         Ile-de-France
# 776882                       NaN            NaN                   NaN
# 776883                    France         Europe                   NaN
# 776884                       NaN            NaN                   NaN
# 776885                       NaN            NaN                   NaN
#
#        state_code                   collected_at candidate
# 0              FL            2020-10-21 00:00:00     trump
# 1             NaN  2020-10-21 00:00:00.373216530     trump
# 2              OR  2020-10-21 00:00:00.746433060     trump
# 3             NaN  2020-10-21 00:00:01.119649591     trump
# 4              DC  2020-10-21 00:00:01.492866121     trump
# ...           ...                            ...       ...
# 776881        IDF     2020-11-09 18:32:45.613547     biden
# 776882        NaN     2020-11-09 18:32:45.947617     biden
# 776883        NaN     2020-11-09 18:32:45.627335     biden
# 776884        NaN     2020-11-09 18:32:45.599846     biden
# 776885        NaN     2020-11-09 18:32:45.747707     biden
#
# [1747805 rows x 22 columns]

# %%
#eda,data cleaning,data pre-processing
# find number of tweets receieved for each of the candidate
data_mixed.groupby(['candidate'])['tweet'].count().plot.bar()
plt.ylabel('number of tweets')
plt.title('Trump vs Biden')
# Out:
# Text(0.5, 1.0, 'Trump vs Biden')

# %%
### comparison of likes
data_mixed.groupby('candidate')['likes'].sum().plot.bar()
plt.ylabel('number of likes')
plt.title('trump vs biden')
# Out:
# Text(0.5, 1.0, 'trump vs biden')

# %%
data_mixed['country'].value_counts()
# Out:
# United States of America    332495
# United States                61905
# United Kingdom               58051
# India                        40091
# Germany                      35379
#                              ...
# Mali                             2
# Northern Mariana Islands         1
# Saint Lucia                      1
# Lesotho                          1
# East Timor                       1
# Name: country, Length: 189, dtype: int64

# %%
## replace united states and united states of america with US
data_mixed['country'] = data_mixed['country'].replace({'United States of America':'US','United States':'US'})

# %%
data_mixed['country'].value_counts()
# Out:
# US                          394400
# United Kingdom               58051
# India                        40091
# Germany                      35379
# France                       35299
#                              ...
# Mali                             2
# Northern Mariana Islands         1
# Saint Lucia                      1
# Lesotho                          1
# East Timor                       1
# Name: country, Length: 188, dtype: int64

# %%
## top 10 countries with highest number of tweets
plt.figure(figsize=(10,5))
data_mixed.groupby('country')['tweet'].count().sort_values(ascending=False).head(10).plot.bar()
plt.ylabel('Number of twwets')
plt.title('Trump vs biden')
# Out:
# Text(0.5, 1.0, 'Trump vs biden')

# %%
# # tweets for biden and trump from each country
top10country = data_mixed.groupby(['country'])['tweet'].count().sort_values(ascending = False).head(10)
top10country = top10country.index.tolist()

# %%
tweetdf = data_mixed.groupby(['country','candidate'])['tweet'].count().reset_index()
tweet_df = tweetdf[tweetdf['country'].isin(top10country)]
tweet_df
# Out:
#             country candidate   tweet
# 16        Australia     biden    5534
# 17        Australia     trump    9365
# 54           Canada     biden   10809
# 55           Canada     trump   16996
# 112          France     biden   14610
# 113          France     trump   20689
# 118         Germany     biden   12761
# 119         Germany     trump   22618
# 146           India     biden   21532
# 147           India     trump   18559
# 160           Italy     biden    8870
# 161           Italy     trump   11206
# 207          Mexico     biden    5092
# 208          Mexico     trump    5811
# 336          Turkey     biden    4774
# 337          Turkey     trump    5594
# 340              US     biden  181137
# 341              US     trump  213263
# 348  United Kingdom     biden   23308
# 349  United Kingdom     trump   34743

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=tweet_df,x='country',y='tweet',hue='candidate')
# Out:
# <Axes: xlabel='country', ylabel='tweet'>

# %%
top10state = data_mixed.groupby(['state'])['tweet'].count().sort_values(ascending = False).head(10).index.tolist()
tweetdf = data_mixed.groupby(['state','candidate'])['tweet'].count().reset_index()
tweet_df = tweetdf[tweetdf['state'].isin(top10state)]
tweet_df
# Out:
#                      state candidate  tweet
# 206             California     biden  25817
# 207             California     trump  31149
# 349   District of Columbia     biden   7055
# 350   District of Columbia     trump   9684
# 386                England     biden  16743
# 387                England     trump  24111
# 410                Florida     biden  13284
# 411                Florida     trump  16568
# 518          Ile-de-France     biden   7001
# 519          Ile-de-France     trump   9393
# 520               Illinois     biden   5500
# 521               Illinois     trump   6777
# 794               New York     biden  21005
# 795               New York     trump  22881
# 869                Ontario     biden   4492
# 870                Ontario     trump   6907
# 899           Pennsylvania     biden   5403
# 900           Pennsylvania     trump   7011
# 1154                 Texas     biden  14191
# 1155                 Texas     trump  16491

# %%
plt.figure(figsize=(20,8))
sns.barplot(data=tweet_df,x='state',y='tweet',hue='candidate')
# Out:
# <Axes: xlabel='state', ylabel='tweet'>

# %%
###################### sentiment analysis of presidential elections
lm = WordNetLemmatizer()

# %%
def clean(text):
    text = str(text).lower()
    text = re.sub('[^a-z]',' ',str(text))
    text = text.split()
    text = [lm.lemmatize(j) for j in text if j not in set(stopwords.words('english'))]
    text = ' '.join(str(k) for k in text)
    return text

# %%
### create function for subjectivity and polarity
## subjectivity --- if the sentence is subjective or objective ---  subjective sentence refer to personal opinion, emotions or people's judgment wheras
## objective sentence refer to factual information . It ranges from [0,1]
# polarity-- float value that lies between [-1,1] where  1 means positive sentiment and -1 means negative sentiment and 0 means neutral.

# %%
###
def getsubjectivity(text):
  return TextBlob(text).sentiment.subjectivity
def getpolarity(text):
  return TextBlob(text).sentiment.polarity
def getAnalysis(score):
  if score<0:
    return 'negative'
  elif score == 0:
    return 'neutral'
  elif score >0 :
    return 'positive'

# %%
trump = data_mixed.query('(candidate == "trump")')

# %%
trump
# Out:
#                  created_at      tweet_id  \
# 0       2020-10-15 00:00:01  1.316529e+18
# 1       2020-10-15 00:00:01  1.316529e+18
# 2       2020-10-15 00:00:02  1.316529e+18
# 3       2020-10-15 00:00:02  1.316529e+18
# 4       2020-10-15 00:00:08  1.316529e+18
# ...                     ...           ...
# 970914  2020-11-08 23:59:43  1.325589e+18
# 970915  2020-11-08 23:59:48  1.325589e+18
# 970916  2020-11-08 23:59:53  1.325589e+18
# 970917  2020-11-08 23:59:54  1.325589e+18
# 970918  2020-11-08 23:59:55  1.325589e+18
#
#                                                     tweet  likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0
# 1       Usa 2020, Trump contro Facebook e Twitter: cop...   26.0
# 2       #Trump: As a student I used to hear for years,...    2.0
# 3       2 hours since last tweet from #Trump! Maybe he...    0.0
# 4       You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# ...                                                   ...    ...
# 970914  @PelleX @Mikerger @spiegelbilderz_ @BertiFranz...    0.0
# 970915  JOE BIDEN WHY JOE BIDEN DID WINNED ?? TRUMP TR...    4.0
# 970916  #AfD|ler reagieren panisch bis hysterisch auf ...   25.0
# 970917  @sammelbis1998 @iheartmindy @bnorthg First, yo...    0.0
# 970918  OK just had to do it !\n#Trump #CatapultTrump ...  105.0
#
#         retweet_count              source       user_id  \
# 0                 0.0           TweetDeck  3.606665e+08
# 1                 9.0    Social Mediaset   3.316176e+08
# 2                 1.0     Twitter Web App  8.436472e+06
# 3                 0.0       Trumpytweeter  8.283556e+17
# 4                 3.0  Twitter for iPhone  4.741380e+07
# ...               ...                 ...           ...
# 970914            0.0     Twitter Web App  3.427951e+09
# 970915            0.0     Twitter Web App  3.245258e+09
# 970916            4.0     Twitter Web App  9.866108e+17
# 970917            0.0    Twitter for iPad  7.687811e+08
# 970918           28.0     Twitter Web App  4.519791e+08
#
#                     user_name user_screen_name  \
# 0          El Sol Latino News  elsollatinonews
# 1                     Tgcom24  MediasetTgcom24
# 2                      snarke           snarke
# 3               Trumpytweeter    trumpytweeter
# 4       Rana Abtar - رنا أبتر        Ranaabtar
# ...                       ...              ...
# 970914      Alexander P. Vogt           APVogt
# 970915                   ahzy           ahhhzy
# 970916               watchdog     wilke_tobias
# 970917                  Debra          drdeblk
# 970918        Dunken K Bliths    DunkenKBliths
#
#                                          user_description  ...  \
# 0       🌐 Noticias de interés para latinos de la costa...  ...
# 1       Profilo ufficiale di Tgcom24: tutte le notizie...  ...
# 2       Will mock for food! Freelance writer, blogger,...  ...
# 3       If he doesn't tweet for some time, should we b...  ...
# 4       Washington Correspondent, Lebanese-American ,c...  ...
# ...                                                   ...  ...
# 970914  Wenn das Aussprechen der Wahrheit »den Falsche...  ...
# 970915                                                NaN  ...
# 970916  Quis custodiet ipsos custodes?\n\nTV Journalis...  ...
# 970917  MD. Autism specialist. Film lover. #DumpTrump2020  ...
# 970918  "Tesla owner's will be followed back"\n\n#Mach...  ...
#
#                        user_location        lat        long        city  \
# 0       Philadelphia, PA / Miami, FL  25.774270  -80.193660         NaN
# 1                                NaN        NaN         NaN         NaN
# 2                           Portland  45.520247 -122.674195    Portland
# 3                                NaN        NaN         NaN         NaN
# 4                      Washington DC  38.894992  -77.036558  Washington
# ...                              ...        ...         ...         ...
# 970914                           NaN        NaN         NaN         NaN
# 970915                           NaN        NaN         NaN         NaN
# 970916                    Saxony/GER        NaN         NaN         NaN
# 970917                           NaN        NaN         NaN         NaN
# 970918    ✔ Official Twitter Account        NaN         NaN         NaN
#
#         country      continent                 state state_code  \
# 0            US  North America               Florida         FL
# 1           NaN            NaN                   NaN        NaN
# 2            US  North America                Oregon         OR
# 3           NaN            NaN                   NaN        NaN
# 4            US  North America  District of Columbia         DC
# ...         ...            ...                   ...        ...
# 970914      NaN            NaN                   NaN        NaN
# 970915      NaN            NaN                   NaN        NaN
# 970916      NaN            NaN                   NaN        NaN
# 970917      NaN            NaN                   NaN        NaN
# 970918      NaN            NaN                   NaN        NaN
#
#                          collected_at candidate
# 0                 2020-10-21 00:00:00     trump
# 1       2020-10-21 00:00:00.373216530     trump
# 2       2020-10-21 00:00:00.746433060     trump
# 3       2020-10-21 00:00:01.119649591     trump
# 4       2020-10-21 00:00:01.492866121     trump
# ...                               ...       ...
# 970914     2020-11-09 17:47:56.036006     trump
# 970915     2020-11-09 17:47:55.715870     trump
# 970916     2020-11-09 17:47:55.975868     trump
# 970917     2020-11-09 17:47:56.012674     trump
# 970918     2020-11-09 17:47:55.807500     trump
#
# [970919 rows x 22 columns]

# %%
trump = trump.query('(country == "US")')

# %%
trump
# Out:
#                  created_at      tweet_id  \
# 0       2020-10-15 00:00:01  1.316529e+18
# 2       2020-10-15 00:00:02  1.316529e+18
# 4       2020-10-15 00:00:08  1.316529e+18
# 5       2020-10-15 00:00:17  1.316529e+18
# 7       2020-10-15 00:00:18  1.316529e+18
# ...                     ...           ...
# 970893  2020-11-08 23:58:46  1.325589e+18
# 970895  2020-11-08 23:58:51  1.325589e+18
# 970897  2020-11-08 23:58:56  1.325589e+18
# 970900  2020-11-08 23:59:05  1.325589e+18
# 970905  2020-11-08 23:59:21  1.325589e+18
#
#                                                     tweet  likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0
# 2       #Trump: As a student I used to hear for years,...    2.0
# 4       You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# 5       @CLady62 Her 15 minutes were over long time ag...    2.0
# 7       @DeeviousDenise @realDonaldTrump @nypost There...    0.0
# ...                                                   ...    ...
# 970893  @DonaldJTrumpJr Being a #tRump you are intimat...    0.0
# 970895  Have you know decency #Trump  @GOP? Do you kno...    3.0
# 970897  LIONZ DEN PRESENTS TO YOU \n\n“THE WHITE OBAMA...    1.0
# 970900  #Trump #Patriots #MAGA2020 https://t.co/2A8Fnm...    0.0
# 970905  Again with the lying, cheating, b.s. #LoserTru...    0.0
#
#         retweet_count               source       user_id  \
# 0                 0.0            TweetDeck  3.606665e+08
# 2                 1.0      Twitter Web App  8.436472e+06
# 4                 3.0   Twitter for iPhone  4.741380e+07
# 5                 0.0  Twitter for Android  1.138416e+09
# 7                 0.0   Twitter for iPhone  9.007611e+17
# ...               ...                  ...           ...
# 970893            0.0     Twitter for iPad  1.237758e+18
# 970895            0.0      Twitter Web App  4.835231e+07
# 970897            0.0  Twitter for Android  9.868225e+17
# 970900            0.0  Twitter for Android  1.296581e+18
# 970905            0.0      Twitter Web App  2.842344e+07
#
#                                          user_name user_screen_name  \
# 0                               El Sol Latino News  elsollatinonews
# 2                                           snarke           snarke
# 4                            Rana Abtar - رنا أبتر        Ranaabtar
# 5                                     Farris Flagg      FarrisFlagg
# 7       Stacey Gulledge 🇺🇸 Patriot ♥️ KAG 🙏 👮‍♀️♥️      sm_gulledge
# ...                                            ...              ...
# 970893                                   U N Known          pirkka2
# 970895      Linda "I Voted for Biden" Kenney Baden      KenneyBaden
# 970897                              IUIC Minnesota    IUICMinnesota
# 970900                           🍿🍷••HellWorld••🍷🍿  HellWor09724785
# 970905              The Honorable Terri Lee Watson        dancertav
#
#                                          user_description  ...  \
# 0       🌐 Noticias de interés para latinos de la costa...  ...
# 2       Will mock for food! Freelance writer, blogger,...  ...
# 4       Washington Correspondent, Lebanese-American ,c...  ...
# 5       #BidenHarris2020 #JoeBiden2020 #KamalaHarrisFo...  ...
# 7       Patriot, Wife, “Shaken not Stirred” Mom of two...  ...
# ...                                                   ...  ...
# 970893  Truth will save the world - not tRump. 🌎 VOTE ...  ...
# 970895  TrialLawyer https://t.co/1C0kKESSUC, Played by...  ...
# 970897                                                NaN  ...
# 970900                                                NaN  ...
# 970905  I'm green, lean and a dancing machine. I draw,...  ...
#
#                        user_location        lat        long        city  \
# 0       Philadelphia, PA / Miami, FL  25.774270  -80.193660         NaN
# 2                           Portland  45.520247 -122.674195    Portland
# 4                      Washington DC  38.894992  -77.036558  Washington
# 5                  Perris,California  33.782519 -117.228648         NaN
# 7                          Ohio, USA  40.225357  -82.688140         NaN
# ...                              ...        ...         ...         ...
# 970893               New Jersey, USA  40.075738  -74.404162         NaN
# 970895                 New York, USA  40.712728  -74.006015    New York
# 970897                Minnesota, USA  45.989659  -94.611329         NaN
# 970900                 Hell on Earth  34.233137 -102.410749         NaN
# 970905                 South Florida  37.167713  -94.846426         NaN
#
#         country      continent                 state state_code  \
# 0            US  North America               Florida         FL
# 2            US  North America                Oregon         OR
# 4            US  North America  District of Columbia         DC
# 5            US  North America            California         CA
# 7            US  North America                  Ohio         OH
# ...         ...            ...                   ...        ...
# 970893       US  North America            New Jersey         NJ
# 970895       US  North America              New York         NY
# 970897       US  North America             Minnesota         MN
# 970900       US  North America                 Texas         TX
# 970905       US  North America                Kansas         KS
#
#                          collected_at candidate
# 0                 2020-10-21 00:00:00     trump
# 2       2020-10-21 00:00:00.746433060     trump
# 4       2020-10-21 00:00:01.492866121     trump
# 5       2020-10-21 00:00:01.866082651     trump
# 7       2020-10-21 00:00:02.612515712     trump
# ...                               ...       ...
# 970893     2020-11-09 17:47:55.744839     trump
# 970895     2020-11-09 17:47:55.833725     trump
# 970897     2020-11-09 17:47:55.847439     trump
# 970900     2020-11-09 17:47:55.939901     trump
# 970905     2020-11-09 17:47:56.062661     trump
#
# [213263 rows x 22 columns]

# %%
trump['cleantext'] = trump['tweet'].apply(clean)
# Out:
# <ipython-input-37-aae32f5f49b2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['cleantext'] = trump['tweet'].apply(clean)

# %%
trump['subjectivity'] = trump['cleantext'].apply(getsubjectivity)
# Out:
# <ipython-input-38-b1ae046213a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['subjectivity'] = trump['cleantext'].apply(getsubjectivity)

# %%
trump['polarity'] = trump['cleantext'].apply(getpolarity)
# Out:
# <ipython-input-39-dd82995b8d20>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['polarity'] = trump['cleantext'].apply(getpolarity)

# %%
trump['score'] = trump['polarity'].apply(getAnalysis)
# Out:
# <ipython-input-40-2782f697029b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trump['score'] = trump['polarity'].apply(getAnalysis)

# %%
biden = data_mixed.query('(candidate == "biden")')
biden = biden.query('(country == "US")')

# %%
biden['cleantext'] = biden['tweet'].apply(clean)

# %%
biden['subjectivity'] = biden['cleantext'].apply(getsubjectivity)

# %%
biden['polarity'] = biden['cleantext'].apply(getpolarity)

# %%
trump
# Out:
#                  created_at      tweet_id  \
# 0       2020-10-15 00:00:01  1.316529e+18
# 2       2020-10-15 00:00:02  1.316529e+18
# 4       2020-10-15 00:00:08  1.316529e+18
# 5       2020-10-15 00:00:17  1.316529e+18
# 7       2020-10-15 00:00:18  1.316529e+18
# ...                     ...           ...
# 970893  2020-11-08 23:58:46  1.325589e+18
# 970895  2020-11-08 23:58:51  1.325589e+18
# 970897  2020-11-08 23:58:56  1.325589e+18
# 970900  2020-11-08 23:59:05  1.325589e+18
# 970905  2020-11-08 23:59:21  1.325589e+18
#
#                                                     tweet  likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0
# 2       #Trump: As a student I used to hear for years,...    2.0
# 4       You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# 5       @CLady62 Her 15 minutes were over long time ag...    2.0
# 7       @DeeviousDenise @realDonaldTrump @nypost There...    0.0
# ...                                                   ...    ...
# 970893  @DonaldJTrumpJr Being a #tRump you are intimat...    0.0
# 970895  Have you know decency #Trump  @GOP? Do you kno...    3.0
# 970897  LIONZ DEN PRESENTS TO YOU \n\n“THE WHITE OBAMA...    1.0
# 970900  #Trump #Patriots #MAGA2020 https://t.co/2A8Fnm...    0.0
# 970905  Again with the lying, cheating, b.s. #LoserTru...    0.0
#
#         retweet_count               source       user_id  \
# 0                 0.0            TweetDeck  3.606665e+08
# 2                 1.0      Twitter Web App  8.436472e+06
# 4                 3.0   Twitter for iPhone  4.741380e+07
# 5                 0.0  Twitter for Android  1.138416e+09
# 7                 0.0   Twitter for iPhone  9.007611e+17
# ...               ...                  ...           ...
# 970893            0.0     Twitter for iPad  1.237758e+18
# 970895            0.0      Twitter Web App  4.835231e+07
# 970897            0.0  Twitter for Android  9.868225e+17
# 970900            0.0  Twitter for Android  1.296581e+18
# 970905            0.0      Twitter Web App  2.842344e+07
#
#                                          user_name user_screen_name  \
# 0                               El Sol Latino News  elsollatinonews
# 2                                           snarke           snarke
# 4                            Rana Abtar - رنا أبتر        Ranaabtar
# 5                                     Farris Flagg      FarrisFlagg
# 7       Stacey Gulledge 🇺🇸 Patriot ♥️ KAG 🙏 👮‍♀️♥️      sm_gulledge
# ...                                            ...              ...
# 970893                                   U N Known          pirkka2
# 970895      Linda "I Voted for Biden" Kenney Baden      KenneyBaden
# 970897                              IUIC Minnesota    IUICMinnesota
# 970900                           🍿🍷••HellWorld••🍷🍿  HellWor09724785
# 970905              The Honorable Terri Lee Watson        dancertav
#
#                                          user_description  ... country  \
# 0       🌐 Noticias de interés para latinos de la costa...  ...      US
# 2       Will mock for food! Freelance writer, blogger,...  ...      US
# 4       Washington Correspondent, Lebanese-American ,c...  ...      US
# 5       #BidenHarris2020 #JoeBiden2020 #KamalaHarrisFo...  ...      US
# 7       Patriot, Wife, “Shaken not Stirred” Mom of two...  ...      US
# ...                                                   ...  ...     ...
# 970893  Truth will save the world - not tRump. 🌎 VOTE ...  ...      US
# 970895  TrialLawyer https://t.co/1C0kKESSUC, Played by...  ...      US
# 970897                                                NaN  ...      US
# 970900                                                NaN  ...      US
# 970905  I'm green, lean and a dancing machine. I draw,...  ...      US
#
#             continent                 state  state_code  \
# 0       North America               Florida          FL
# 2       North America                Oregon          OR
# 4       North America  District of Columbia          DC
# 5       North America            California          CA
# 7       North America                  Ohio          OH
# ...               ...                   ...         ...
# 970893  North America            New Jersey          NJ
# 970895  North America              New York          NY
# 970897  North America             Minnesota          MN
# 970900  North America                 Texas          TX
# 970905  North America                Kansas          KS
#
#                          collected_at candidate  \
# 0                 2020-10-21 00:00:00     trump
# 2       2020-10-21 00:00:00.746433060     trump
# 4       2020-10-21 00:00:01.492866121     trump
# 5       2020-10-21 00:00:01.866082651     trump
# 7       2020-10-21 00:00:02.612515712     trump
# ...                               ...       ...
# 970893     2020-11-09 17:47:55.744839     trump
# 970895     2020-11-09 17:47:55.833725     trump
# 970897     2020-11-09 17:47:55.847439     trump
# 970900     2020-11-09 17:47:55.939901     trump
# 970905     2020-11-09 17:47:56.062661     trump
#
#                                                 cleantext subjectivity  \
# 0       elecciones en florida joebiden dice que donald...     0.000000
# 2       trump student used hear year ten year heard ch...     0.333333
# 4       get tie get tie trump rally iowa http co jjaluumh     0.000000
# 5       clady minute long time ago omarosa never repre...     0.416667
# 7       deeviousdenise realdonaldtrump nypost many unl...     0.533333
# ...                                                   ...          ...
# 970893  donaldjtrumpjr trump intimately familiar disgu...     0.750000
# 970895  know decency trump gop know like child die bil...     0.700000
# 970897  lionz den present white obama get ready live f...     0.371429
# 970900                  trump patriot maga http co fnm ux     0.000000
# 970905  lying cheating b losertrump camp protest broke...     0.000000
#
#         polarity     score
# 0       0.000000   neutral
# 2       0.333333  positive
# 4       0.000000   neutral
# 5      -0.108333  negative
# 7       0.050000  positive
# ...          ...       ...
# 970893 -0.312500  negative
# 970895 -0.600000  negative
# 970897 -0.021753  negative
# 970900  0.000000   neutral
# 970905  0.000000   neutral
#
# [213263 rows x 26 columns]

# %%
biden['score'] = biden['polarity'].apply(getAnalysis)

# %%
biden
# Out:
#                  created_at      tweet_id  \
# 0       2020-10-15 00:00:01  1.316529e+18
# 2       2020-10-15 00:00:20  1.316529e+18
# 4       2020-10-15 00:00:22  1.316529e+18
# 6       2020-10-15 00:00:25  1.316529e+18
# 11      2020-10-15 00:00:57  1.316529e+18
# ...                     ...           ...
# 776861  2020-11-08 23:58:09  1.325588e+18
# 776862  2020-11-08 23:58:10  1.325588e+18
# 776865  2020-11-08 23:58:24  1.325589e+18
# 776870  2020-11-08 23:58:48  1.325589e+18
# 776872  2020-11-08 23:58:56  1.325589e+18
#
#                                                     tweet  likes  \
# 0       #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0
# 2       @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...    0.0
# 4       #censorship #HunterBiden #Biden #BidenEmails #...    1.0
# 6       In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 11      FBI Allegedly Obtained Hunter Biden Computer, ...    0.0
# ...                                                   ...    ...
# 776861  #election #2020Elections #trump #biden https:/...    0.0
# 776862  @GOP @GOPLeader @senatemajldr @LindseyGrahamSC...    0.0
# 776865  @FLOTUS I’m excited to have a FLOTUS whose vag...    0.0
# 776870  The man needs some help...#usa #biden\nWhen wi...    0.0
# 776872  LIONZ DEN PRESENTS TO YOU \n\n“THE WHITE OBAMA...    1.0
#
#         retweet_count               source       user_id  \
# 0                 0.0            TweetDeck  3.606665e+08
# 2                 0.0      Twitter Web App  3.494182e+09
# 4                 0.0      Twitter Web App  1.032807e+18
# 6                 0.0   Twitter for iPhone  1.994033e+07
# 11                0.0  Twitter for Android  9.607387e+17
# ...               ...                  ...           ...
# 776861            0.0   Twitter for iPhone  9.538012e+17
# 776862            0.0  Twitter for Android  2.975783e+09
# 776865            0.0   Twitter for iPhone  5.545625e+07
# 776870            0.0  Twitter for Android  1.248047e+18
# 776872            0.0  Twitter for Android  9.868225e+17
#
#                                                 user_name user_screen_name  \
# 0                                      El Sol Latino News  elsollatinonews
# 2                                              Flag Waver      Flag_Wavers
# 4                                          the Gold State    theegoldstate
# 6       Change Illinois | Biden will increase taxes by...   changeillinois
# 11                                              RLCompton   NewfoundStudio
# ...                                                   ...              ...
# 776861                                    NY Gay and MAGA        NYMike912
# 776862                                      OnCapeCodTime  CapeCodBluesArt
# 776865                                 Caroline Billinson       cbillinson
# 776870                                               Dr J    DrJoeMcCarthy
# 776872                                     IUIC Minnesota    IUICMinnesota
#
#                                          user_description  ... country  \
# 0       🌐 Noticias de interés para latinos de la costa...  ...      US
# 2                                                     NaN  ...      US
# 4       A Silicon Valley #independent #News #Media #St...  ...      US
# 6       Illinois, home of Lincoln and Reagan, used to ...  ...      US
# 11      "There are things known and there are things u...  ...      US
# ...                                                   ...  ...     ...
# 776861  Gay proud. not a liberal. I was always a Democ...  ...      US
# 776862  Indigenous American w/Scottish, Irish, German ...  ...      US
# 776865    my love language is dismantling the patriarchy.  ...      US
# 776870  Human. Free Thinker. Met Mandela. Personal. Fa...  ...      US
# 776872                                                NaN  ...      US
#
#             continent                 state  state_code  \
# 0       North America               Florida          FL
# 2       North America               Montana          MT
# 4       North America            California          CA
# 6       North America              Illinois          IL
# 11      North America              Kentucky          KY
# ...               ...                   ...         ...
# 776861  North America              New York          NY
# 776862  North America         Massachusetts          MA
# 776865  North America  District of Columbia          DC
# 776870  North America                 Idaho          ID
# 776872  North America             Minnesota          MN
#
#                          collected_at candidate  \
# 0                 2020-10-21 00:00:00     biden
# 2       2020-10-21 00:00:01.035654566     biden
# 4       2020-10-21 00:00:02.071309132     biden
# 6       2020-10-21 00:00:03.106963698     biden
# 11      2020-10-21 00:00:05.696100113     biden
# ...                               ...       ...
# 776861     2020-11-09 18:32:45.608982     biden
# 776862     2020-11-09 18:32:45.973973     biden
# 776865     2020-11-09 18:32:45.841439     biden
# 776870     2020-11-09 18:32:45.641087     biden
# 776872     2020-11-09 18:32:45.794545     biden
#
#                                                 cleantext subjectivity  \
# 0       elecciones en florida joebiden dice que donald...     0.000000
# 2       islandgirlprv bradbeauregardj meidastouch bide...     0.000000
# 4       censorship hunterbiden biden bidenemails biden...     0.000000
# 6       nypost censorship censored twitter manipulate ...     0.678571
# 11      fbi allegedly obtained hunter biden computer d...     0.100000
# ...                                                   ...          ...
# 776861     election election trump biden http co cvkctsyl     0.000000
# 776862  gop gopleader senatemajldr lindseygrahamsc tak...     0.000000
# 776865  flotus excited flotus whose vagina seen twitte...     0.750000
# 776870        man need help usa biden go http co f dj syt     0.000000
# 776872  lionz den present white obama get ready live f...     0.371429
#
#         polarity     score
# 0       0.000000   neutral
# 2       0.000000   neutral
# 4       0.000000   neutral
# 6      -0.148810  negative
# 11     -0.100000  negative
# ...          ...       ...
# 776861  0.000000   neutral
# 776862  0.000000   neutral
# 776865  0.375000  positive
# 776870  0.000000   neutral
# 776872 -0.021753  negative
#
# [181137 rows x 26 columns]

# %%
trump = trump[['cleantext','score','polarity','subjectivity']]

# %%
biden = biden[['cleantext','score','polarity','subjectivity']]

# %%
trump
# Out:
#                                                 cleantext     score  polarity  \
# 0       elecciones en florida joebiden dice que donald...   neutral  0.000000
# 2       trump student used hear year ten year heard ch...  positive  0.333333
# 4       get tie get tie trump rally iowa http co jjaluumh   neutral  0.000000
# 5       clady minute long time ago omarosa never repre...  negative -0.108333
# 7       deeviousdenise realdonaldtrump nypost many unl...  positive  0.050000
# ...                                                   ...       ...       ...
# 970893  donaldjtrumpjr trump intimately familiar disgu...  negative -0.312500
# 970895  know decency trump gop know like child die bil...  negative -0.600000
# 970897  lionz den present white obama get ready live f...  negative -0.021753
# 970900                  trump patriot maga http co fnm ux   neutral  0.000000
# 970905  lying cheating b losertrump camp protest broke...   neutral  0.000000
#
#         subjectivity
# 0           0.000000
# 2           0.333333
# 4           0.000000
# 5           0.416667
# 7           0.533333
# ...              ...
# 970893      0.750000
# 970895      0.700000
# 970897      0.371429
# 970900      0.000000
# 970905      0.000000
#
# [213263 rows x 4 columns]

# %%
trump.score.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
biden.score.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
biden.score.value_counts()
# Out:
# neutral     84721
# positive    66093
# negative    30323
# Name: score, dtype: int64

# %%
trump.score.value_counts()
# Out:
# neutral     92097
# positive    72568
# negative    48598
# Name: score, dtype: int64

# %%
### word cloud
from wordcloud import WordCloud, STOPWORDS
def word_cloud(wd_list):
  stopwords =set(STOPWORDS)
  all_words  = ' '.join([text for text in wd_list])
  wordcloud = WordCloud(background_color='white',stopwords = stopwords,
                        width = 1600,height =800, max_words =100,max_font_size=200).generate(all_words)
  plt.figure(figsize=(12,10))
  plt.imshow(wordcloud)

# %%
word_cloud(trump['cleantext'][:5000])

# %%
word_cloud(biden['cleantext'][:5000])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\KIIT\Desktop\ML_Model\Devtown\Sentiment_Analysis\Sentiment_Analy (1).ipynb Cell 52 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KIIT/Desktop/ML_Model/Devtown/Sentiment_Analysis/Sentiment_Analy%20%281%29.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> word_cloud(biden['cleantext'][:5000])
#
# NameError: name 'word_cloud' is not defined

# %%
pip install word_cloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018E6C8BF190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/word-cloud/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018E6C8BFC90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/word-cloud/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000018E6C8D0250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/word-cloud/
# ERROR: Could not find a version that satisfies the requirement word_cloud (from versions: none)
# ERROR: No matching distribution found for word_cloud
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
